# %% [markdown]
# # Updating DataFrame Values

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
houses = pd.read_csv("/content/drive/MyDrive/DEPI/Data/kc_house_data.csv")
titanic = pd.read_csv("/content/drive/MyDrive/DEPI/Data/titanic.csv")
netflix = pd.read_csv("/content/drive/MyDrive/DEPI/Data/netflix_titles.csv", sep="|", index_col=0)
btc = pd.read_csv("/content/drive/MyDrive/DEPI/Data/coin_Bitcoin.csv")
countries = pd.read_csv("/content/drive/MyDrive/DEPI/Data/world-happiness-report-2021.csv", index_col=0)

# %% [markdown]
# ## Rename

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
mapper ={"Regional indicator": "regional_indicator", "Ladder score": "ladder_score"}
countries.rename(columns=mapper).head()
# Out:
#              regional_indicator  ladder_score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark          Western Europe         7.620                           0.035
# Switzerland      Western Europe         7.571                           0.036
# Iceland          Western Europe         7.554                           0.059
# Netherlands      Western Europe         7.464                           0.027
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Switzerland          7.643         7.500                 11.117
# Iceland              7.670         7.438                 10.878
# Netherlands          7.518         7.410                 10.932
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %%
countries.columns
# Out:
# Index(['Regional indicator', 'Ladder score', 'Standard error of ladder score',
#        'upperwhisker', 'lowerwhisker', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
mapper={"Western Europe":"western europe"}
countries["Regional indicator"]=countries["Regional indicator"].replace(mapper).head()
countries
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          western europe         7.842                           0.032
# Denmark          western europe         7.620                           0.035
# Switzerland      western europe         7.571                           0.036
# Iceland          western europe         7.554                           0.059
# Netherlands      western europe         7.464                           0.027
# ...                         ...           ...                             ...
# Lesotho                     NaN         3.512                           0.120
# Botswana                    NaN         3.467                           0.074
# Rwanda                      NaN         3.415                           0.068
# Zimbabwe                    NaN         3.145                           0.058
# Afghanistan                 NaN         2.523                           0.038
#
# ...

# %%
mapper = {"Finland": "finland", "Denmark": "denmark"}
countries.rename(index=mapper).head()
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# finland          western europe         7.842                           0.032
# denmark          western europe         7.620                           0.035
# Switzerland      western europe         7.571                           0.036
# Iceland          western europe         7.554                           0.059
# Netherlands      western europe         7.464                           0.027
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# finland              7.904         7.780                 10.775
# denmark              7.687         7.552                 10.933
# Switzerland          7.643         7.500                 11.117
# Iceland              7.670         7.438                 10.878
# Netherlands          7.518         7.410                 10.932
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %% [markdown]
# ## Replace

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["sex"].replace("female", "F", inplace=True)

# %%
titanic["sex"].replace(["female", "male"], ["F", "M"],inplace=True)

# %%
titanic
# Out:
#       pclass  survived                                             name sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton   F
# 1          1         1                   Allison, Master. Hudson Trevor   M
# 2          1         0                     Allison, Miss. Helen Loraine   F
# 3          1         0             Allison, Mr. Hudson Joshua Creighton   M
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   F
# ...      ...       ...                                              ...  ..
# 1304       3         0                             Zabour, Miss. Hileni   F
# 1305       3         0                            Zabour, Miss. Thamine   F
# 1306       3         0                        Zakarian, Mr. Mapriededer   M
# 1307       3         0                              Zakarian, Mr. Ortin   M
# 1308       3         0                               Zimmerman, Mr. Leo   M
#
# ...

# %%
titanic["age"].replace("?", "Unknown").value_counts()
# Out:
# age
# Unknown    263
# 24          47
# 22          43
# 21          41
# 30          40
#           ...
# 66           1
# 0.6667       1
# 76           1
# 67           1
# 26.5         1
# Name: count, Length: 99, dtype: int64

# %%
titanic["age"].replace("?", None).value_counts()
# Out:
# age
# 24        47
# 22        43
# 21        41
# 30        40
# 18        39
#           ..
# 0.3333     1
# 22.5       1
# 70.5       1
# 0.6667     1
# 26.5       1
# Name: count, Length: 98, dtype: int64

# %%
titanic["age"].replace(["?"], [None]).value_counts(dropna=False)
# Out:
# age
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: count, Length: 99, dtype: int64

# %%
titanic["age"].replace(["?"], [None], inplace=True)

# %%
countries
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          western europe         7.842                           0.032
# Denmark          western europe         7.620                           0.035
# Switzerland      western europe         7.571                           0.036
# Iceland          western europe         7.554                           0.059
# Netherlands      western europe         7.464                           0.027
# ...                         ...           ...                             ...
# Lesotho                     NaN         3.512                           0.120
# Botswana                    NaN         3.467                           0.074
# Rwanda                      NaN         3.415                           0.068
# Zimbabwe                    NaN         3.145                           0.058
# Afghanistan                 NaN         2.523                           0.038
#
# ...

# %% [markdown]
# ## Updating With .loc[ ]

# %%
countries.loc["Brazil"]
# Out:
# Regional indicator                               NaN
# Ladder score                                    6.33
# Standard error of ladder score                 0.043
# upperwhisker                                   6.415
# lowerwhisker                                   6.245
# Logged GDP per capita                          9.577
# Social support                                 0.882
# Healthy life expectancy                       66.601
# Freedom to make life choices                   0.804
# Generosity                                    -0.071
# Perceptions of corruption                      0.756
# Ladder score in Dystopia                        2.43
# Explained by: Log GDP per capita               1.028
# Explained by: Social support                   0.944
# Explained by: Healthy life expectancy          0.571
# Explained by: Freedom to make life choices     0.514
# Explained by: Generosity                       0.142
# Explained by: Perceptions of corruption        0.117
# ...

# %%
countries.loc["Brazil",["Healthy life expectancy","Dystopia + residual"]]
# Out:
# Healthy life expectancy    66.601
# Dystopia + residual         3.015
# Name: Brazil, dtype: object

# %%
countries.loc["Brazil", ["Ladder score", "Healthy life expectancy"]]
# Out:
# Ladder score                 6.33
# Healthy life expectancy    66.601
# Name: Brazil, dtype: object

# %%
countries.loc[["Costa Rica", "Panama", "Panama", "Honduras"], ["Ladder score", "Healthy life expectancy"]]
# Out:
#               Ladder score  Healthy life expectancy
# Country name
# Costa Rica           7.069                   71.400
# Panama               6.180                   69.652
# Panama               6.180                   69.652
# Honduras             5.919                   67.300

# %%
countries.loc[["Denmark", "Sweden", "Norway"], ["Regional indicator"]]
# Out:
#              Regional indicator
# Country name
# Denmark          western europe
# Sweden                      NaN
# Norway                      NaN

# %%
countries.loc[["Denmark", "Sweden", "Norway"], ["Regional indicator"]]
# Out:
#              Regional indicator
# Country name
# Denmark          western europe
# Sweden                      NaN
# Norway                      NaN

# %%
countries.loc[["Denmark", "Sweden", "Norway"], ["Regional indicator"]] = "Scandinavia"

# %%
countries.head(10)
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          western europe         7.842                           0.032
# Denmark             Scandinavia         7.620                           0.035
# Switzerland      western europe         7.571                           0.036
# Iceland          western europe         7.554                           0.059
# Netherlands      western europe         7.464                           0.027
# Norway              Scandinavia         7.392                           0.035
# Sweden              Scandinavia         7.363                           0.036
# Luxembourg                  NaN         7.324                           0.037
# New Zealand                 NaN         7.277                           0.040
# Austria                     NaN         7.268                           0.036
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# ...

# %%
countries.loc["Finland"] = "LOL"
# Out:
# <ipython-input-34-ac39e3187deb>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'LOL' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   countries.loc["Finland"] = "LOL"

# %%
countries.loc["Finland", ["upperwhisker", "lowerwhisker"]] = "MEOW"

# %%
countries
# Out:
#              Regional indicator Ladder score Standard error of ladder score  \
# Country name
# Finland                     LOL          LOL                            LOL
# Denmark             Scandinavia         7.62                          0.035
# Switzerland      western europe        7.571                          0.036
# Iceland          western europe        7.554                          0.059
# Netherlands      western europe        7.464                          0.027
# ...                         ...          ...                            ...
# Lesotho                     NaN        3.512                           0.12
# Botswana                    NaN        3.467                          0.074
# Rwanda                      NaN        3.415                          0.068
# Zimbabwe                    NaN        3.145                          0.058
# Afghanistan                 NaN        2.523                          0.038
#
# ...

# %%
countries.loc[["Finland", "Denmark", "Iceland", "Sweden", "Norway"]]
# Out:
#              Regional indicator Ladder score Standard error of ladder score  \
# Country name
# Finland                     LOL          LOL                            LOL
# Denmark             Scandinavia         7.62                          0.035
# Iceland          western europe        7.554                          0.059
# Sweden              Scandinavia        7.363                          0.036
# Norway              Scandinavia        7.392                          0.035
#
#              upperwhisker lowerwhisker Logged GDP per capita Social support  \
# Country name
# Finland              MEOW         MEOW                   LOL            LOL
# Denmark             7.687        7.552                10.933          0.954
# Iceland              7.67        7.438                10.878          0.983
# Sweden              7.433        7.293                10.867          0.934
# Norway              7.462        7.323                11.053          0.954
#
# ...

# %%
countries.loc[["Finland", "Denmark", "Iceland", "Sweden", "Norway"], ['Regional indicator', 'isCold']] = "DOGS!!!"
# Out:
# <ipython-input-38-9b0e703dbf90>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'DOGS!!!' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   countries.loc[["Finland", "Denmark", "Iceland", "Sweden", "Norway"], ['Regional indicator', 'isCold']] = "DOGS!!!"

# %%
countries.loc[["Finland", "Denmark", "Iceland", "Sweden", "Norway"]]
# Out:
#              Regional indicator Ladder score Standard error of ladder score  \
# Country name
# Finland                 DOGS!!!          LOL                            LOL
# Denmark                 DOGS!!!         7.62                          0.035
# Iceland                 DOGS!!!        7.554                          0.059
# Sweden                  DOGS!!!        7.363                          0.036
# Norway                  DOGS!!!        7.392                          0.035
#
#              upperwhisker lowerwhisker Logged GDP per capita Social support  \
# Country name
# Finland              MEOW         MEOW                   LOL            LOL
# Denmark             7.687        7.552                10.933          0.954
# Iceland              7.67        7.438                10.878          0.983
# Sweden              7.433        7.293                10.867          0.934
# Norway              7.462        7.323                11.053          0.954
#
# ...

# %%
countries.loc[["Finland", "Denmark", "Iceland", "Sweden", "Norway"], ['Regional indicator', 'isCold']] = ["Nordic Countries", "yes!" ]

# %%
many_bedrooms = houses["bedrooms"] >= 10

# %%
many_bedrooms=houses["bedrooms"]>=10
houses.loc[many_bedrooms,"bedrooms"]
# Out:
# 8757     11
# 13314    10
# 15161    10
# 15870    33
# 19254    10
# Name: bedrooms, dtype: int64

# %%
houses.loc[many_bedrooms, ['bedrooms']] = "TOO MANY!"
# Out:
# <ipython-input-45-38ccb1cedaba>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'TOO MANY!' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   houses.loc[many_bedrooms, ['bedrooms']] = "TOO MANY!"

# %%
houses[many_bedrooms]
# Out:
#                id             date      price   bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0  TOO MANY!       3.00
# 13314   627300145  20140814T000000  1148000.0  TOO MANY!       5.25
# 15161  5566100170  20141029T000000   650000.0  TOO MANY!       2.00
# 15870  2402100895  20140625T000000   640000.0  TOO MANY!       1.75
# 19254  8812401450  20141229T000000   660000.0  TOO MANY!       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
houses
# Out:
#                id             date     price bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900.0        3       1.00         1180
# 1      6414100192  20141209T000000  538000.0        3       2.25         2570
# 2      5631500400  20150225T000000  180000.0        2       1.00          770
# 3      2487200875  20141209T000000  604000.0        4       3.00         1960
# 4      1954400510  20150218T000000  510000.0        3       2.00         1680
# ...           ...              ...       ...      ...        ...          ...
# 21608   263000018  20140521T000000  360000.0        3       2.50         1530
# 21609  6600060120  20150223T000000  400000.0        4       2.50         2310
# 21610  1523300141  20140623T000000  402101.0        2       0.75         1020
# 21611   291310100  20150116T000000  400000.0        3       2.50         1600
# 21612  1523300157  20141015T000000  325000.0        2       0.75         1020
#
# ...

# %%
high_quality = houses["grade"] > 12
great_views = houses["view"] == 4

# %%
houses['luxury_level'] = "normal"

# %%
houses
# Out:
#                id             date     price bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900.0        3       1.00         1180
# 1      6414100192  20141209T000000  538000.0        3       2.25         2570
# 2      5631500400  20150225T000000  180000.0        2       1.00          770
# 3      2487200875  20141209T000000  604000.0        4       3.00         1960
# 4      1954400510  20150218T000000  510000.0        3       2.00         1680
# ...           ...              ...       ...      ...        ...          ...
# 21608   263000018  20140521T000000  360000.0        3       2.50         1530
# 21609  6600060120  20150223T000000  400000.0        4       2.50         2310
# 21610  1523300141  20140623T000000  402101.0        2       0.75         1020
# 21611   291310100  20150116T000000  400000.0        3       2.50         1600
# 21612  1523300157  20141015T000000  325000.0        2       0.75         1020
#
# ...

# %%
houses.loc[high_quality & great_views, ['luxury_level']] = 'ultra'

# %%
houses["luxury_level"].value_counts()
# Out:
# luxury_level
# normal    21610
# ultra         3
# Name: count, dtype: int64
